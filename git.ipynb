# %% [markdown]
# - git
#     - 基本命令
#         - init
#
#         - status
#
#         - add
#
#         - commit -m "version name"
#
#         - reset --hard 版本编码
#
#         - log/reflog
#
#         - branch 查看分支
#
#         - branch xxx  创建
#             - -d 删除分支
#
#         - checkout master/xxx 切换分支
#
#         - merge 合并分支
#             - 注意和合并到哪儿就切换到那个分支
#
#             -
#
#
#     - 区域划分
#
#         - 工作区
#             - 所在文件夹
#
#         - 暂存区
#             - add后的
#
#         - 版本库
#             - commit后的
#
#
#     - 分支
#         - 做环境的隔离
#
#         - 是什么
#             保留共同的文件，记录新文件
#
#         - bug紧急修复（创建分支，修复版本即可）
#
#         -
#     - 工作流
#         - 规范
#
#
#     - git与github
#         - 本地向github仓库推代码
#
#             - git remote add origin url 起个昵称
#
#             - git push -u origin 分支
#
#         - 从github仓库克隆代码
#
#             - git clone url
